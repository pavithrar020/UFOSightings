# %%
import pandas as pd
import ipywidgets

# %%
ufo = pd.read_csv(r'desktop/ufo-scrubbed-geocoded-time-standardized-00.csv')

# %%
ufo
# Out:
#           Sighting Date                  City State Country    Type  Seconds  \
# 0      10/10/1949 21:00          lackland afb    tx     NaN   light   7200.0
# 1      10/10/1955 17:00  chester (uk/england)   NaN      gb  circle     20.0
# 2      10/10/1956 21:00                  edna    tx      us  circle     20.0
# 3      10/10/1960 20:00               kaneohe    hi      us   light    900.0
# 4      10/10/1961 19:00               bristol    tn      us  sphere    300.0
# ...                 ...                   ...   ...     ...     ...      ...
# 80326    9/9/2013 21:15             nashville    tn      us   light    600.0
# 80327    9/9/2013 22:00                 boise    id      us  circle   1200.0
# 80328    9/9/2013 22:00                  napa    ca      us   other   1200.0
# 80329    9/9/2013 22:20                vienna    va      us  circle      5.0
# 80330    9/9/2013 23:00                edmond    ok      us   cigar   1020.0
#
# ...

# %%
df=pd.DataFrame(ufo)

# %%
df
# Out:
#           Sighting Date                  City State Country    Type  Seconds  \
# 0      10/10/1949 21:00          lackland afb    tx     NaN   light   7200.0
# 1      10/10/1955 17:00  chester (uk/england)   NaN      gb  circle     20.0
# 2      10/10/1956 21:00                  edna    tx      us  circle     20.0
# 3      10/10/1960 20:00               kaneohe    hi      us   light    900.0
# 4      10/10/1961 19:00               bristol    tn      us  sphere    300.0
# ...                 ...                   ...   ...     ...     ...      ...
# 80326    9/9/2013 21:15             nashville    tn      us   light    600.0
# 80327    9/9/2013 22:00                 boise    id      us  circle   1200.0
# 80328    9/9/2013 22:00                  napa    ca      us   other   1200.0
# 80329    9/9/2013 22:20                vienna    va      us  circle      5.0
# 80330    9/9/2013 23:00                edmond    ok      us   cigar   1020.0
#
# ...

# %%
plotty = df.plot.scatter(x='Long', y='Lat')

# %%
df[df['State']=='ca']
# Out:
#           Sighting Date       City State Country       Type  Seconds  \
# 9      10/10/1968 13:00  hawthorne    ca      us     circle    300.0
# 29     10/10/1979 22:00  san diego    ca      us       oval    180.0
# 44     10/10/1989 00:00  calabasas    ca      us       disk    300.0
# 62     10/10/1995 22:40    oakland    ca      us        NaN     60.0
# 71     10/10/1998 02:30  hollywood    ca      us   changing    300.0
# ...                 ...        ...   ...     ...        ...      ...
# 80298    9/9/2012 20:00     arcata    ca      us  formation    600.0
# 80304    9/9/2012 20:30    ventura    ca      us    chevron    900.0
# 80309    9/9/2012 21:00    ventura    ca      us     circle    300.0
# 80315    9/9/2013 09:51  san diego    ca      us      light      4.0
# 80328    9/9/2013 22:00       napa    ca      us      other   1200.0
#
#               Times                                        Description  \
# ...

# %%
plotty =df[df['State']=='ca'].plot.scatter(x='Long', y='Lat')

# %%
plotty =df[df['State']=='ca'].plot.scatter(x='Long', y='Lat')

# %%
state = ipywidgets.Textarea()

# %%
state
# Out:
# Textarea(value='ca')

# %%
plotty =df[df['State']==state.value].plot.scatter(x='Long', y='Lat')
